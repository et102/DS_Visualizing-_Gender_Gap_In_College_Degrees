# %% [markdown]
# #### Visualizing the gender gap across college degrees
# #### Eric Tsai (yytsai1002@gmail.com)
# #### Oct 2018

# %% [markdown]
# ### Gender gap among STEM degrees

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('../data/percent_bachelors_degrees_women_usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']


fig = plt.figure(figsize=(18, 3)) ## set fig size: 18 inch * 3 inch

for sp in range(0,6):
    ax = fig.add_subplot(1,6,sp+1)    ## divide subplot 。1 row X 6 column
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        
## export results
plt.savefig('STEM.png')

# %% [markdown]
# ### Gender gap among liberal arts

# %%
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)


lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']

fig = plt.figure(figsize=(18, 3)) ## set fig size: 18 inch * 3 inch

for sp in range(0,5):
    ax = fig.add_subplot(1,5,sp+1)    ## divide subplot 。1 row X 5 column
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')

## export results
plt.savefig('Liberal_arts.png')

# %% [markdown]
# ### Gender gap for the remaining degress

# %%
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)


others = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']


fig = plt.figure(figsize=(18, 3)) ## set fig size: 18 inch * 3 inch

for sp in range(0,6):
    ax = fig.add_subplot(1,6,sp+1)    ## divide subplot 。1 row X 5 column
    ax.plot(women_degrees['Year'], women_degrees[others[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[others[sp]], c=cb_orange, label='Men', linewidth=3)
    
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')

## export results
plt.savefig('others.png')
